# %%
a='C,B,A'
b=['F','G','H']
c= a.split(',')
d=c+b
d[0]='K'
e=d.pop(2)
del d[1:4]
d.append('U')
print(d)
print(e)
# Out:
# ['K', 'H', 'U']
# A

# %%
a=input('請輸入一個八位數數字:')
print(a[4])
# Out:
# 請輸入一個八位數數字:12345678
# 5

# %%
a=('My ID is B1202021')
c=a.split()
print(len(c))
b=(a[9:])
print(len(b))
# Out:
# 4
# 8

# %%
a=("「I'm a student」")
b=a.split('m')
print(a[len(b[0])])
# Out:
# m
